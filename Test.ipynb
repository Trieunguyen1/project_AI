# %% [markdown]
# <a href="https://colab.research.google.com/github/Trieunguyen1/project_AI/blob/main/Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import load_img, img_to_array

# %%
from tensorflow.keras.models import load_model
model = load_model('/content/gdrive/MyDrive/train_model_garbage_CNN.h5')

# %%
img=load_img("/content/test_pin1.jpg",target_size=(384, 512))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model.predict(img)
if round(result[0][0])==1:
  prediction='battery'
if round(result[0][1])==1:
  prediction='cardboard'
if round(result[0][2])==1:
  prediction='glass'
if round(result[0][3])==1:
  prediction='metal'
if round(result[0][4])==1:
  prediction='paper'
if round(result[0][5])==1:
  prediction='plastic'
print(prediction)
# Out:
# 1/1 [==============================] - 1s 724ms/step
# battery

# %%
img=load_img("/content/test_pin2.jpg",target_size=(384, 512))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model.predict(img)
if round(result[0][0])==1:
  prediction='battery'
if round(result[0][1])==1:
  prediction='cardboard'
if round(result[0][2])==1:
  prediction='glass'
if round(result[0][3])==1:
  prediction='metal'
if round(result[0][4])==1:
  prediction='paper'
if round(result[0][5])==1:
  prediction='plastic'
print(prediction)
# Out:
# 1/1 [==============================] - 1s 741ms/step
# battery

# %%
img=load_img("/content/metal.jpg",target_size=(384, 512))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model.predict(img)
if round(result[0][0])==1:
  prediction='battery'
if round(result[0][1])==1:
  prediction='cardboard'
if round(result[0][2])==1:
  prediction='glass'
if round(result[0][3])==1:
  prediction='metal'
if round(result[0][4])==1:
  prediction='paper'
if round(result[0][5])==1:
  prediction='plastic'
print(prediction)
# Out:
# 1/1 [==============================] - 0s 324ms/step
# metal

# %%
img=load_img("/content/glass.jpg",target_size=(384, 512))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model.predict(img)
if round(result[0][0])==1:
  prediction='battery'
if round(result[0][1])==1:
  prediction='cardboard'
if round(result[0][2])==1:
  prediction='glass'
if round(result[0][3])==1:
  prediction='metal'
if round(result[0][4])==1:
  prediction='paper'
if round(result[0][5])==1:
  prediction='plastic'
print(prediction)
# Out:
# 1/1 [==============================] - 0s 491ms/step
# glass

# %%
img=load_img("/content/cardboard.jpg",target_size=(384, 512))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model.predict(img)
if round(result[0][0])==1:
  prediction='battery'
if round(result[0][1])==1:
  prediction='glass'
if round(result[0][2])==1:
  prediction='cardboard'
if round(result[0][3])==1:
  prediction='metal'
if round(result[0][4])==1:
  prediction='paper'
if round(result[0][5])==1:
  prediction='plastic'
print(prediction)
# Out:
# 1/1 [==============================] - 0s 273ms/step
# battery

# %%
img=load_img("/content/paper46.jpg",target_size=(384, 512))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model.predict(img)
if round(result[0][0])==1:
  prediction='battery'
if round(result[0][1])==1:
  prediction='glass'
if round(result[0][2])==1:
  prediction='cardboard'
if round(result[0][3])==1:
  prediction='metal'
if round(result[0][4])==1:
  prediction='paper'
if round(result[0][5])==1:
  prediction='plastic'
print(prediction)
# Out:
# 1/1 [==============================] - 0s 366ms/step
# paper
